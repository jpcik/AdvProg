// %% [markdown]
// # Scala: Strings
//
// Strings and chars. Types can be inferred by the compiler.

// %%
val course = "History"
// Out:
// course: String = "History"

// %%
val grade='B'
// Out:
// grade: Char = 'B'

// %% [markdown]
// ## Strings and AnyRef
//
// Strings, as other complex types in Scala, inherit from `AnyRef`.

// %%
val someRef:AnyRef = "my string"
// Out:
// someRef: Object = "my string"

// %%
someRef + "adding"
// Out:
// -- [E008] Not Found Error: cmd2.sc:1:19 ----------------------------------------
// 1 |val res2 = someRef + "adding"
//   |           ^^^^^^^^^
//   |value + is not a member of AnyRef, but could be made available as an extension method.
//   |
//   |One of the following imports might make progress towards fixing the problem:
//   |
//   |  import math.Fractional.Implicits.infixFractionalOps
//   |  import math.Integral.Implicits.infixIntegralOps
//   |  import math.Numeric.Implicits.infixNumericOps
//   |Compilation Failed
// Compilation Failed

// %% [markdown]
// As we can see, the methods for manipulating the strings are not available in AnyRef.
//
// We can cast any `String` as `AnyRef`, as a consequence of that inheritance.

// %%
val oneString:String = "one string"

val oneRef:AnyRef = oneString
// Out:
// oneString: String = "one string"
// oneRef: Object = "one string"

// %% [markdown]
// ## String interpolation
//
// String interpolation can be useful to mix strings and variables which are preceded by the `$` symbol.

// %%
val note = s"Your grade in $course is $grade."
println(note)
// Out:
// Your grade in History is B.
// note: String = "Your grade in History is B."

// %% [markdown]
// String interpolation can also be ised to introduce full expressions enclosed in `${ }`

// %%
val grade1 = 5.5
val grade2 = 3.2
def add(x:Int)=x+2
s"Your final grade is ${(grade1 + grade2) /2}. Bye."
// Out:
// grade1: Double = 5.5
// grade2: Double = 3.2
// defined function add
// res5_3: String = "Your final grade is 4.35. Bye."

// %% [markdown]
// ## Other common String features and operations
//
// Multi-line strings can be specified using triple `"""  """`

// %%
val poem = """The grass is green
            The sky is blue
            The river flows
            And the trees sleep."""
// Out:
// poem: String = """The grass is green
//             The sky is blue
//             The river flows
//             And the trees sleep."""

// %% [markdown]
// Common methods to split, trim, substring, etc. are available.

// %%
"sometext".split('e')
// Out:
// res7: Array[String] = Array("som", "t", "xt")

// %%
"231,;231,213;324234".split(",|;")
// Out:
// res8: Array[String] = Array("231", "", "231", "213", "324234")
