// %%
val num = 3f
// Out:
// num: Float = 3.0F

// %%
val any:AnyVal = num
// Out:
// any: AnyVal = 3.0F

// %%
3 + any
// Out:
// -- [E134] Type Error: cmd2.sc:1:12 ---------------------------------------------
// 1 |val res2 = 3+any
//   |           ^^
//   |   None of the overloaded alternatives of method + in class Int with types
//   |    (x: Double): Double
//   |    (x: Float): Float
//   |    (x: Long): Long
//   |    (x: Int): Int
//   |    (x: Char): Int
//   |    (x: Short): Int
//   |    (x: Byte): Int
//   |    (x: String): String
//   |   match arguments ((cmd2.this.cmd1.any : AnyVal))Compilation Failed
// Compilation Failed

// %%
3 + any.asInstanceOf[Float]
// Out:
// res2: Float = 6.0F

// %%
val name = "Nelson"
// Out:
// name: String = "Nelson"

// %%
val any:AnyRef = name
// Out:
// any: Object = "Nelson"

// %%
any + "Mandela"
// Out:
// -- [E008] Not Found Error: cmd5.sc:1:15 ----------------------------------------
// 1 |val res5 = any + "Mandela"
//   |           ^^^^^
//   |value + is not a member of AnyRef, but could be made available as an extension method.
//   |
//   |One of the following imports might make progress towards fixing the problem:
//   |
//   |  import math.Fractional.Implicits.infixFractionalOps
//   |  import math.Integral.Implicits.infixIntegralOps
//   |  import math.Numeric.Implicits.infixNumericOps
//   |Compilation Failed
// Compilation Failed

// %%
any.asInstanceOf[String] + " Mandela"
// Out:
// res6: String = "Nelson Mandela"

// %%
val nada:Null = "something"
// Out:
// -- [E007] Type Mismatch Error: cmd7.sc:1:16 ------------------------------------
// 1 |val nada:Null = "something"
//   |                ^^^^^^^^^^^
//   |                Found:    ("something" : String)
//   |                Required: Null
//   |
//   | longer explanation available when compiling with `-explain`Compilation Failed
// Compilation Failed

// %%
var nada:Null = null
// Out:
// nada: Null = null

// %%
nada = "something"
// Out:
// -- [E007] Type Mismatch Error: cmd9.sc:1:18 ------------------------------------
// 1 |val res9 = nada = "something"
//   |                  ^^^^^^^^^^^
//   |                  Found:    ("something" : String)
//   |                  Required: Null
//   |
//   | longer explanation available when compiling with `-explain`Compilation Failed
// Compilation Failed

// %%
val niente:Nothing = null
// Out:
// -- [E007] Type Mismatch Error: cmd9.sc:1:19 ------------------------------------
// 1 |val nada:Nothing = null
//   |                   ^^^^
//   |                   Found:    Null
//   |                   Required: Nothing
//   |
//   | longer explanation available when compiling with `-explain`Compilation Failed
// Compilation Failed

// %%
val niente:Nothing = throw new Exception
// Out:
// java.lang.Exception
//   ammonite.$sess.cmd9$Helper.<init>(cmd9.sc:1)
//   ammonite.$sess.cmd9$.<clinit>(cmd9.sc:65410)

// %%
val niente:Nothing = ???
// Out:
// scala.NotImplementedError: an implementation is missing
//   scala.Predef$.$qmark$qmark$qmark(Predef.scala:344)
//   ammonite.$sess.cmd10$Helper.<init>(cmd10.sc:1)
//   ammonite.$sess.cmd10$.<clinit>(cmd10.sc:65410)

// %%
case class Student(name:String, age:Int)
// Out:
// defined class Student

// %%
val p:Product = new Student("Pete",23)
// Out:
// p: Product = Student(name = "Pete", age = 23)

// %%
for elemName <- p.productElementNames do
    println(elemName)
// Out:
// name
// age

// %%
for element <- p.productIterator do
    println(element)
// Out:
// Pete
// 23

// %%
val tuple = ("Jim",5.5,6,3.4)
// Out:
// tuple: (String, Double, Int, Double) = ("Jim", 5.5, 6, 3.4)

// %%
tuple._1
// Out:
// res7: String = "Jim"

// %%
tuple._3
// Out:
// res8: Int = 6

// %%
tuple._5
// Out:
// -- [E008] Not Found Error: cmd9.sc:1:17 ----------------------------------------
// 1 |val res9 = tuple._5
//   |           ^^^^^^^^
//   |value _5 is not a member of (String, Double, Int, Double) - did you mean tuple._1?Compilation Failed
// Compilation Failed

// %%
tuple.size
// Out:
// res9: Int = 4

// %%
val (name,age,grade) = ("Joe",34,6)
// Out:
// name: String = "Joe"
// age: Int = 34
// grade: Int = 6

// %%
grade
// Out:
// res14: Int = 6

// %%
tuple match
    case ("Jim",_,_,_) => println("found")
    case _ => println("unfound")
// Out:
// found

// %%
tuple match
    case (s:String,_,_,_) => println("gotcha")
    case _ => println("nein")
// Out:
// gotcha

// %%
val tuple2 = ("Nancy",5.5) ++ (4.5,5.3)
// Out:
// tuple2: *:[String, *:[Double, (Double, Double)]] = ("Nancy", 5.5, 4.5, 5.3)

// %%
tuple2._3
// Out:
// res20: Double = 4.5

// %%
tuple2(2)
// Out:
// res21: Double = 4.5

// %%
tuple2.toList
// Out:
// res22: List[scala.collection.immutable.List[java.lang.String | scala.Double | scala.Double | scala.Double | scala.Nothing]] = List("Nancy", 5.5, 4.5, 5.3)
