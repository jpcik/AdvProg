// %%
val num = 3f
// Out:
// num: Float = 3.0F

// %%
val any:AnyVal = num
// Out:
// any: AnyVal = 3.0F

// %%
3 + any
// Out:
// -- [E134] Type Error: cmd2.sc:1:12 ---------------------------------------------
// 1 |val res2 = 3+any
//   |           ^^
//   |   None of the overloaded alternatives of method + in class Int with types
//   |    (x: Double): Double
//   |    (x: Float): Float
//   |    (x: Long): Long
//   |    (x: Int): Int
//   |    (x: Char): Int
//   |    (x: Short): Int
//   |    (x: Byte): Int
//   |    (x: String): String
//   |   match arguments ((cmd2.this.cmd1.any : AnyVal))Compilation Failed
// Compilation Failed

// %%
3 + any.asInstanceOf[Float]
// Out:
// res2: Float = 6.0F

// %%
val name = "Nelson"
// Out:
// name: String = "Nelson"

// %%
val any:AnyRef = name
// Out:
// any: Object = "Nelson"

// %%
any + "Mandela"
// Out:
// -- [E008] Not Found Error: cmd5.sc:1:15 ----------------------------------------
// 1 |val res5 = any + "Mandela"
//   |           ^^^^^
//   |value + is not a member of AnyRef, but could be made available as an extension method.
//   |
//   |One of the following imports might make progress towards fixing the problem:
//   |
//   |  import math.Fractional.Implicits.infixFractionalOps
//   |  import math.Integral.Implicits.infixIntegralOps
//   |  import math.Numeric.Implicits.infixNumericOps
//   |Compilation Failed
// Compilation Failed

// %%
any.asInstanceOf[String] + " Mandela"
// Out:
// res6: String = "Nelson Mandela"

// %%
val nada:Null = "something"
// Out:
// -- [E007] Type Mismatch Error: cmd7.sc:1:16 ------------------------------------
// 1 |val nada:Null = "something"
//   |                ^^^^^^^^^^^
//   |                Found:    ("something" : String)
//   |                Required: Null
//   |
//   | longer explanation available when compiling with `-explain`Compilation Failed
// Compilation Failed

// %%
var nada:Null = null
// Out:
// nada: Null = null

// %%
nada = "something"
// Out:
// -- [E007] Type Mismatch Error: cmd9.sc:1:18 ------------------------------------
// 1 |val res9 = nada = "something"
//   |                  ^^^^^^^^^^^
//   |                  Found:    ("something" : String)
//   |                  Required: Null
//   |
//   | longer explanation available when compiling with `-explain`Compilation Failed
// Compilation Failed

// %%
val niente:Nothing = null
// Out:
// -- [E007] Type Mismatch Error: cmd9.sc:1:19 ------------------------------------
// 1 |val nada:Nothing = null
//   |                   ^^^^
//   |                   Found:    Null
//   |                   Required: Nothing
//   |
//   | longer explanation available when compiling with `-explain`Compilation Failed
// Compilation Failed

// %%
val niente:Nothing = throw new Exception
// Out:
// java.lang.Exception
//   ammonite.$sess.cmd9$Helper.<init>(cmd9.sc:1)
//   ammonite.$sess.cmd9$.<clinit>(cmd9.sc:65410)

// %%
val niente:Nothing = ???
// Out:
// scala.NotImplementedError: an implementation is missing
//   scala.Predef$.$qmark$qmark$qmark(Predef.scala:344)
//   ammonite.$sess.cmd10$Helper.<init>(cmd10.sc:1)
//   ammonite.$sess.cmd10$.<clinit>(cmd10.sc:65410)
